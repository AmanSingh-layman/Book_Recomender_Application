# %%
import os

import pandas as pd
from dotenv import load_dotenv
books = pd.read_csv("data_test/books_cleaned.csv")

load_dotenv()
os.environ["GOOGLE_API_KEY"] = "AIzaSyDlRO4062KgN98t1zx1hpZp2QxO0jj1htE"

# %%
from langchain.vectorstores import Chroma
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.document_loaders import DirectoryLoader
from langchain.document_loaders import TextLoader,CSVLoader,JSONLoader

# %%
loader=DirectoryLoader("data_test",glob="./*.txt",loader_cls=lambda path: TextLoader(path,encoding='utf-8')) #document loader

# %%
document=loader.load()

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter

text_splitter=RecursiveCharacterTextSplitter(chunk_size=500,chunk_overlap=100)
text=text_splitter.split_documents(document)

# %%
len(text)
# Out:
# 7357

# %% [markdown]
# # CREATING VECTOR-DATABASE

# %%
persist_directory="db_books"

# %%
embedding = GoogleGenerativeAIEmbeddings(model="models/embedding-001")

# %%
vectordb=Chroma.from_documents(
    documents=text,
    embedding=embedding,
    persist_directory=persist_directory
)

# %%
vectordb.persist()

# %%
vectordb=None

# %%
vectordb=Chroma(persist_directory=persist_directory,embedding_function=embedding)

# %%
vectordb

# %% [markdown]
# # MAKING QUERIES

# %%
retriver=vectordb.as_retriever()

# %%
query="A book to teach children about nature"
docs=retriver.get_relevant_documents(query,k=3)

# %%
docs
# Out:
# [Document(metadata={'source': 'data_test\\tagged_description.txt'}, page_content='9780786808069 Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience.'),
#  Document(metadata={'source': 'data_test\\tagged_description.txt'}, page_content='9780786808069 Children will discover the exciting world of their own backyard in this introduction to familiar animals from cats and dogs to bugs and frogs. The combination of photographs, illustrations, and fun facts make this an accessible and delightful learning experience.'),
#  Document(metadata={'source': 'data_test\\tagged_description.txt'}, page_content="and a guide to capturing the simple power of discovery that Carson views as essential to life. In her insightful new introduction, Linda Lear remembers Rachel Carson's groundbreaking achievements in the context of the legendary environmentalist's personal commitment to introducing young and old to the miracles of nature. Kelsh's lush photographs inspire sensual, tactile reactions: masses of leaves floating in a puddle are just waiting to be scooped up and examined more closely. An image of a")]

# %%
books[books["isbn13"] == int(docs[0].page_content.split()[0].strip())]
# Out:
#              isbn13      isbn10                                title  \
# 3747  9780786808069  0786808063  Baby Einstein: Neighborhood Animals
#
#                                 authors        categories  \
# 3747  Marilyn Singer;Julie Aigner-Clark  Juvenile Fiction
#
#                                               thumbnail  \
# 3747  http://books.google.com/books/content?id=X9a4P...
#
#                                             description  published_year  \
# 3747  Children will discover the exciting world of t...          2001.0
#
#       average_rating  num_pages  ratings_count  missing_values  \
# 3747            3.89       16.0          180.0               0
#
#       missing_decription                   title_and_subtitle  \
# 3747                   0  Baby Einstein: Neighborhood Animals
#
#                                      tagged_description
# 3747  9780786808069 Children will discover the excit...

# %%
def retrieve_semantic_recommendation(
        query: str,
        top_k: int = 10,
) -> pd.DataFrame:
    recs = retriver.get_relevant_documents(query, k=50)
    books_list = []

    for i in range(0, len(recs)):
        try:
            # Ensure that there is content to parse
            content = recs[i].page_content.strip('"')
            if content:
                isbn = content.split()[0]  # Attempt to get the first word as ISBN
                # Optionally, you can validate the ISBN format here if needed
                books_list.append(int(isbn))  # Only add to list if it's a valid ISBN
        except Exception as e:
            print(f"Error processing document {i}: {e}")

    # Filter the books by ISBN and return
    return books[books["isbn13"].isin(books_list)]

# %%
retrieve_semantic_recommendation("A book to teach children about nature")
# Out:
# Error processing document 2: invalid literal for int() with base 10: 'and'
# Error processing document 3: invalid literal for int() with base 10: 'and'
# Error processing document 6: invalid literal for int() with base 10: 'in'
# Error processing document 7: invalid literal for int() with base 10: 'in'
# Error processing document 8: invalid literal for int() with base 10: 'wildlife,'
# Error processing document 9: invalid literal for int() with base 10: 'wildlife,'
# Error processing document 14: invalid literal for int() with base 10: 'two'
# Error processing document 15: invalid literal for int() with base 10: 'two'
# Error processing document 20: invalid literal for int() with base 10: 'floating'
# Error processing document 21: invalid literal for int() with base 10: 'floating'
# Error processing document 40: invalid literal for int() with base 10: 'needs'
# Error processing document 41: invalid literal for int() with base 10: 'needs'
#              isbn13      isbn10  \
# 228   9780060782139  0060782137
# 429   9780064434980  0064434982
# 442   9780067575208  006757520X
# 1077  9780240806082  0240806085
# 1907  9780393315110  0393315118
# 2112  9780439405577  0439405572
# 2503  9780486276809  0486276805
# 3198  9780689716041  0689716044
# 3201  9780689823824  0689823827
# 3203  9780689834196  0689834195
# 3215  9780689862465  0689862466
# 3522  9780753459645  0753459647
# 3747  9780786808069  0786808063
# 3748  9780786808373  0786808373
# 3749  9780786808380  0786808381
# 3750  9780786808397  078680839X
# 3751  9780786808717  0786808713
# 3770  9780786855384  078685538X
# 4241  9780915811236  0915811235
#
#                                                   title  \
# 228                         Time For Kids: Butterflies!
# 429                                The Deer in the Wood
# 442                                 The Sense of Wonder
# 1077                          Directing the Documentary
# 1907  Uncommon Ground: Rethinking the Human Place in...
# 2112             Don't Know Much about American History
# 2503                    The Secret Garden Coloring Book
# 3198                      The Bears on Hemlock Mountain
# 3201                         A Child's Garden of Verses
# 3203                                  Salt in His Shoes
# 3215                                        The Octopus
# 3522                         I Wonder Why the Sun Rises
# 3747                Baby Einstein: Neighborhood Animals
# 3748                               Baby Einstein: Birds
# 3749                              Baby Einstein: Babies
# 3750                                Baby Einstein: Dogs
# 3751  Baby Einstein: What Does Violet See? Raindrops...
# 3770         Disney's Little Einsteins: Butterfly Suits
# 4241                     Secret of the Peaceful Warrior
#
#                                 authors           categories  \
# 228            Editors of TIME For Kids  Juvenile Nonfiction
# 429                Laura Ingalls Wilder     Juvenile Fiction
# 3751  A very special puddle sets Violet the mouse of...          2002.0
# 3770  When Annie's new caterpillar friend misses his...          2006.0
# 4241  An old man named Socrates shows Danny that the...          1991.0
#
#       average_rating  num_pages  ratings_count  missing_values  \
# 228             4.00       32.0           20.0               0
# 429             4.17       32.0          302.0               0
# 442             4.39      112.0         1160.0               0
# 1077            4.23      648.0          173.0               0
# 1907            4.16      560.0          649.0               0
# 2112            3.90      222.0        21169.0               0
# 2503            4.25       48.0            4.0               0
# 3198            3.78       64.0         2017.0               0
# 3201            4.30       67.0        21780.0               0
# 3203            4.21       32.0         1054.0               0
# 3215            4.16       64.0          117.0               0
# 3522            3.95       32.0           50.0               0
# 3747            3.89       16.0          180.0               0
# 3748            3.78       20.0            9.0               0
# 3749            4.03       20.0           29.0               0
# 3750            3.81       20.0           26.0               0
# 3751            3.25       18.0           16.0               0
# 3770            3.68       32.0           26.0               0
# 4241            4.18       32.0          152.0               0
#
#       missing_decription                                 title_and_subtitle  \
# 228                    0                        Time For Kids: Butterflies!
# 429                    0                               The Deer in the Wood
# 442                    0                                The Sense of Wonder
# 1077                   0                          Directing the Documentary
# 1907                   0  Uncommon Ground: Rethinking the Human Place in...
# 2112                   0             Don't Know Much about American History
# 2503                   0                    The Secret Garden Coloring Book
# 3198                   0                      The Bears on Hemlock Mountain
# 3201                   0                         A Child's Garden of Verses
# 3203                   0  Salt in His Shoes: Michael Jordan in Pursuit o...
# 3215                   0                                        The Octopus
# 3522                   0  I Wonder Why the Sun Rises: and Other Question...
# 3747                   0                Baby Einstein: Neighborhood Animals
# 3748                   0                               Baby Einstein: Birds
# 3749                   0                              Baby Einstein: Babies
# 3750                   0                                Baby Einstein: Dogs
# 3751                   0  Baby Einstein: What Does Violet See? Raindrops...
# 3770                   0         Disney's Little Einsteins: Butterfly Suits
# 4241                   0                     Secret of the Peaceful Warrior
#
#                                      tagged_description
# 228   9780060782139 Butterflies There are 20,000 dif...
# 429   9780064434980 Even the youngest child can enjo...
# 442   9780067575208 First published more than three ...
# 1077  9780240806082 Michael Rabiger guides the reade...
# 1907  9780393315110 Essays by revisionist historians...
# 2112  9780439405577 Presents, in question and answer...
# 2503  9780486276809 Ten-year-old Mary comes to live ...
# 3198  9780689716041 An eight-year-old boy who is fri...
# 3201  9780689823824 Here is a delightful look at chi...
# 3203  9780689834196 Young Michael Jordan, who is sma...
# 3215  9780689862465 Whistler and Lila, two of the mi...
# 3522  9780753459645 What is a leap year? Why are bee...
# 3747  9780786808069 Children will discover the excit...
# 3748  9780786808373 Introducing your baby to birds, ...
# 3749  9780786808380 Introduce your babies to birds, ...
# 3750  9780786808397 Introduce your baby to birds, ca...
# 3751  9780786808717 A very special puddle sets Viole...
# 3770  9780786855384 When Annie's new caterpillar fri...
# 4241  9780915811236 An old man named Socrates shows ...
